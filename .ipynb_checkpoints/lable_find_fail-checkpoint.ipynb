# %% [markdown]
# # lable결정

# %%
import pandas as pd
ori_data = pd.read_csv("responses.csv")
data = ori_data
data.head()
# Out:
#    Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0    5.0                       3.0    2.0   1.0      2.0              2.0
# 1    4.0                       4.0    2.0   1.0      1.0              1.0
# 2    5.0                       5.0    2.0   2.0      3.0              4.0
# 3    5.0                       3.0    2.0   1.0      1.0              1.0
# 4    5.0                       3.0    4.0   3.0      2.0              4.0
#
#    Musical  Pop  Rock  Metal or Hardrock           ...             Age  \
# 0      1.0  5.0   5.0                1.0           ...            20.0
# 1      2.0  3.0   5.0                4.0           ...            19.0
# 2      5.0  3.0   5.0                3.0           ...            20.0
# 3      1.0  2.0   2.0                1.0           ...            22.0
# 4      3.0  5.0   3.0                1.0           ...            20.0
#
#    Height  Weight  Number of siblings  Gender  Left - right handed  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1010 entries, 0 to 1009
# Columns: 150 entries, Music to House - block of flats
# dtypes: float64(134), int64(5), object(11)
# memory usage: 1.2+ MB

# %%
data.describe()
# Out:
#              Music  Slow songs or fast songs        Dance         Folk  \
# count  1007.000000               1008.000000  1006.000000  1005.000000
# mean      4.731877                  3.328373     3.113320     2.288557
# std       0.664049                  0.833931     1.170568     1.138916
# min       1.000000                  1.000000     1.000000     1.000000
# 25%       5.000000                  3.000000     2.000000     1.000000
# 50%       5.000000                  3.000000     3.000000     2.000000
# 75%       5.000000                  4.000000     4.000000     3.000000
# max       5.000000                  5.000000     5.000000     5.000000
#
#            Country  Classical music      Musical          Pop         Rock  \
# count  1005.000000      1003.000000  1008.000000  1007.000000  1004.000000
# mean      2.123383         2.956132     2.761905     3.471698     3.761952
# std       1.076136         1.252570     1.260845     1.161400     1.184861
# ...

# %%
corr_matrix = data.corr()
corr_matrix["Music"].sort_values(ascending=True)
# Out:
# Weight                           -0.130746
# Eating to survive                -0.081713
# Age                              -0.076829
# Politics                         -0.072768
# Mathematics                      -0.069702
# Height                           -0.068953
# Physics                          -0.068848
# Western                          -0.063580
# Gardening                        -0.046249
# Prioritising workload            -0.045614
# Fake                             -0.042723
# Heights                          -0.042436
# Documentary                      -0.038650
# War                              -0.035345
# Law                              -0.033674
# Finances                         -0.032529
# Charity                          -0.029594
# Economy Management               -0.025346
# Horror                           -0.025005
# God                              -0.023091
# Flying                           -0.022756
# Religion                         -0.019674
# ...

# %%
corr_matrix["Age"].sort_values(ascending=True)
# Out:
# Changing the past         -0.147357
# Shopping centres          -0.133868
# Questionnaires or polls   -0.126586
# Getting up                -0.119694
# Mood swings               -0.111618
# Cheating in school        -0.107587
# Animated                  -0.101916
# Foreign languages         -0.096988
# Shopping                  -0.095809
# Chemistry                 -0.077257
# Music                     -0.076829
# Spiders                   -0.076575
# Spending on looks         -0.072659
# Branded clothing          -0.066279
# Loneliness                -0.066186
# Comedy                    -0.066016
# Fun with friends          -0.065944
# Romantic                  -0.065062
# Sci-fi                    -0.064702
# Hiphop, Rap               -0.063344
# Appearence and gestures   -0.060721
# Biology                   -0.056772
# Self-criticism            -0.053260
# Life struggles            -0.053163
# Darkness                  -0.047962
# Hypochondria              -0.046140
# ...

# %%
corr_matrix["Spending on gadgets"].sort_values(ascending=True)
# Out:
# Life struggles                   -0.211767
# Folk                             -0.155887
# Reading                          -0.150605
# Empathy                          -0.143804
# Dangerous dogs                   -0.136862
# Flying                           -0.131646
# Storm                            -0.126367
# Fantasy/Fairy tales              -0.122089
# Romantic                         -0.114039
# Latino                           -0.107433
# Decision making                  -0.104983
# Darkness                         -0.100194
# Finances                         -0.097290
# Unpopularity                     -0.096258
# Children                         -0.095628
# Responding to a serious letter   -0.092315
# God                              -0.089195
# Chemistry                        -0.084098
# Musical                          -0.075305
# Writing notes                    -0.075244
# Heights                          -0.071972
# Religion                         -0.069739
# ...

# %%
corr_matrix["Number of siblings"].sort_values(ascending=True)
# Out:
# Loss of interest             -0.088395
# Spending on healthy eating   -0.082345
# Celebrities                  -0.078784
# Shopping                     -0.067315
# Shopping centres             -0.064048
# Borrowed stuff               -0.061461
# Pets                         -0.061324
# Getting up                   -0.059854
# Public speaking              -0.058942
# Pop                          -0.057928
# Compassion to animals        -0.053902
# Appearence and gestures      -0.051127
# Law                          -0.048811
# Spiders                      -0.047102
# Fear of public speaking      -0.047073
# Comedy                       -0.046060
# Reliability                  -0.045406
# Spending on looks            -0.041896
# Heights                      -0.041723
# Finances                     -0.039973
# Branded clothing             -0.039901
# Healthy eating               -0.038847
# Mood swings                  -0.038456
# Hiphop, Rap                  -0.036785
# ...
